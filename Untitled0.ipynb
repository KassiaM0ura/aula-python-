# %% [markdown]
# <a href="https://colab.research.google.com/github/KassiaM0ura/aula-python-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
angulo=float(input("digite o angulo que voce deseja: "))
seno=math.sin(math.radians(angulo))
print("o angulo de {}, tem o SENO de {:.2f}". format(angulo, seno ))
cosseno= math.cos(math.radians(angulo))
print("o angulo de {}, tem o COSSENO de {:.2f}". format(angulo, cosseno))
tangente= math.tan(math.radians(angulo))
print("o  angulo de {}, tem a TANGENTE de {:.2f}". format(angulo, tangente ))

# %%
import random
nome1=(input("digite o seu nome e trabalho:"))
nome2=(input("digite o seu nome e trabalho:"))
nome3=(input("digite o seu nome e trabalho:"))
nome4=(input("digite o seu nome e trabalho:"))
nomes=[nome1, nome2, nome3, nome4]
random.shuffle(nomes)
print("aluno sorteado é {} \n".format (nomes))

# %%
import pygame
pygame.init()
pygame.mixer.music.load('ex.mp3')
pygame.mixer.music.play()
pygame.event.wait()

# %%
frase= (input("qual o seu nome? "))
print(frase.upper(), )

# %%
frase2=str(input("digite seu primeiro nome:"))
frase= str(input(" digite o restante do seu nome: "))
nome=(frase2)+(" ")+(frase)
print("seu nome completo é", (nome))
print("com letras maiusculas", nome.upper())
print("com letras minusculas:", nome.lower())
print("Quantas letras tem seu nome:", len(nome.strip()))
print("Seu primeiro nome em maiusculo:", len(frase2))

# %%
numero= int(input("informe um numero:"))
u = numero //  1 % 10
d = numero // 10 % 10
c = numero // 100 % 10
m = numero // 10 % 10
print("analisando o numero {}".format (numero))
print("unidade{}".format(u))
print("dezena{}".format(d))
print("centena{}".format(c))
print("milhar{}".format(m))

# %%
cid=str(input("qual a sua cidade: ")).strip()
print(cid[:5], "tem santo no nome entao é:" in cid )

# %%
nome=str(input("qual é o seu nome :")).strip()
print("seu nome {}, tem silva? {}".format(nome,"silva" in nome ))

# %%
ano= int(input("Quantos anos tem seu carro?"))
if ano<=3:
  print("carro novo")
else:
  print("carro velho")
  print("--fim--")

# %%
nome= (input("qual é o seu nome: "))
if nome == "gustavo":
  print(" que nome lindo, bom dia ", nome)
else:
  print("bom dia!", nome )

# %%
n1= float(input("digite sua primeira nota:"))
n2= float(input("digite a sua segunda nota:"))
media= (n1+n2)/2
print("sua primeira nota é {},\n sua segunda nota é {}, \n sua media é {:.2}".format(n1, n2, media ))
if media<6:
  print("aluno reprovado")
else:
  print("aluno aprovado")

# %%
velocidade=float(input("digite sua velocidade"))
if velocidade>80:
   print("voce foi multado")
   multa= (velocidade-80) * 7
   print("sua multa ficou no valor de ", multa )
else:
   print("voce esta no limite")

# %%
nume=int(input("digite um numero:"))
if nume % 2  == 0:
  print("é par")
else:
  print("é impar")

# %%
Dis=float(input("digite dua velocidade em km : "))
if Dis<=200:
  valor= Dis*0.50
  print(" valor cobrado é {}".format(valor))

else:
  valor= Dis*0.45
  print("valor cobrado é {}".format(valor))

# %%
ano= int(input("digite o ano: "))
if ano % 4 ==0:
  print("ano bissexto")
elif ano % 400==0:
  print("ano bissexto")
else:
  print("ano não bissexto ")

# %%
salario= float(input("digite seu salario:"))
if salario> 1.250:
    novo= salario + (salario * 15/100)
    print("Seu novo salario é {}".format(novo))
else:
     salario * (salario * 10/100)
     print("seu novo salario é {}".format(salario))
# Out:
# digite seu salario:3500
# Seu novo salario é 4025.0

# %%
print("-=" * 20)
print("avaliador de segmentos")
print("-=" * 20)
r1=float(input("Primeiro segmento: "))
r2=float(input("Segundo segmento: "))
r3=float(input("terceiro segmento: "))
if r1<r2+ r3 and r2<r1 +r3 and r3<r1+r2:
  print(" os segmentos acima pode formamr triangulo ")
else:
  print("os segmentos acima não pode formar triangulo ")
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# avaliador de segmentos
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Primeiro segmento: 3
# Segundo segmento: 4
# terceiro segmento: 10
# os segmentos acima não pode formar triangulo
